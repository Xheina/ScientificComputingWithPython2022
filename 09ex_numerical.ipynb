# %% [markdown]
# 1\. **2D minimization of a six-hump camelback function**
#
# $$f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2$$
#
# has multiple global and local minima.
#
# - Find the global minima of this function
# - How many global minima are there, and what is the function value at those points?
# - What happens for an initial guess of $(x, y) = (0, 0)$?
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use `numpy.meshgrid()` and `pylab.imshow()` to find visually the regions.
# * Use `scipy.optimize.minimize()`, optionally trying its optional arguments.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import optimize
from scipy import fftpack
from matplotlib.colors import LogNorm
from scipy.integrate import odeint
def f(x):
    return ((4-2.1*x[0]**2+x[0]**4/3)*x[0]**2+ x[0]*x[1]+ (4*x[1]**2-4)*x[1]**2)

x = np.linspace(-2, 2, 100)
y = np.linspace(-1, 1, 100)

x, y = np.meshgrid(x, y)

z = np.zeros((100,100))

for i in range (100):
    for j in range (100):
        z[i,j]= f(np.array([x[i,j],y[i,j]]))

        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(x, y, z,100)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")


minimum = optimize.minimize(f,(-0.5,-0.5)) 
#Plot the minimum 
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(x, y, z,100,cmap="binary")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.scatter(minimum["x"][0],minimum["x"][1],f(minimum["x"]),marker="x",color = "b",s=100)


#Plot the minimum when the initial guess of (𝑥,𝑦)=(0,0)
minimum = optimize.minimize(f,(0,0))
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(x, y, z,100,cmap="binary")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.scatter(minimum["x"][0],minimum["x"][1],f(minimum["x"]),marker="x",color = "b",s=100)

# %% [markdown]
# 2\. **Non-linear ODE: the damped pendulum**
#
# The equation of the motion that a pendulum makes with respect to the angle $\theta$ with the vertical is given by:
#
# $$\frac{d^2\theta}{dt^2} = -\frac{1}{Q} \frac{d\theta}{dt} + \sin\theta + d \cos\Omega t$$
#
# where $t$ is time, $Q$ is the damping factor, $d$ is the forcing amplitude, and $\Omega$ is the driving frequency of the forcing.
#
# This second order ODE needs to be written as two coupled first order ODEs defining a new variable $\omega \equiv d\theta/dt$:
#
# $$\frac{d\theta}{dt} = \omega$$
# $$\frac{d\omega}{dt} = -\frac{1}{Q}\,\omega + \sin\theta + d \cos\Omega t$$
#
# Consider the initial conditions $\theta_0 = \omega_0 = 0$, and $Q = 2.0$, $d = 1.5$, and $\omega = 0.65$.
#
#  - Solve the ODE with `odeint` over a pariod of 200 time steps
#  - Create two plots, one of $\theta$ as a function of the time, and $\omega$ as a function of the time
#  - **Optional**: determine if there is a set of parameters for which the motion is chaotic.

# %%
def damped_pendulum(W, time):
    Q=2
    d=1.5
    omega=0.65
    return(W[1], -(1/Q)*W[1]+np.sin(W[0])+d*np.cos(omega*time))
W=(0,0) 
t = np.linspace(0, 100,200) 
solution = odeint(damped_pendulum, W, t)


theta=solution[:, 0]
omega=solution[:, 1]
plt.figure(figsize=(10, 10))
plt.plot(t, theta, c="m")
plt.xlabel("time")
plt.ylabel("Theta(rad)")


plt.figure(figsize=(10, 10))
plt.plot(t, omega, c="m")
plt.xlabel("time")
plt.ylabel("Omega(rad)")
# Out:
# Text(0, 0.5, 'Omega(rad)')

# %% [markdown]
# 3\. **FFT of a simple dataset**
#
# Perform a periodicity analysis on the lynxs-hares population, i.e. determine what is the period of the population of these animals.
#
# The dataset is the one dowloaded at the beginning of Lecture 06:
#
#  - `!wget https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt -P data/`

# %%
# !wget --no-check-certificate https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt -P data/
dataset = np.loadtxt('/Users/User/Downloads/populations.txt')
year, hares, lynxes, _ = dataset.T 

plt.plot(year, lynxes, label = "Lynxes")
plt.plot(year, hares, label = "Hares")
plt.legend()
plt.show()

l_fft = fftpack.fft(lynxes)
h_fft = fftpack.fft(hares)

l_abs = np.abs(l_fft)
h_abs = np.abs(h_fft)

time_stamp = year[1]-year[0]
l_freq = fftpack.fftfreq(lynxes.size, d=time_stamp)
h_freq = fftpack.fftfreq(hares.size, d=time_stamp)

plt.plot(l_freq, l_abs, label = 'Lynxes')
plt.plot(h_freq, h_abs, label = 'Hares')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power')
plt.legend()
plt.show()
# Out:
# --2023-01-20 21:07:05--  https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# WARNING: cannot verify www.dropbox.com's certificate, issued by 'CN=DigiCert TLS RSA SHA256 2020 CA1,O=DigiCert Inc,C=US':
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/ebe1cnyd2gm836a/populations.txt [following]
# --2023-01-20 21:07:06--  https://www.dropbox.com/s/raw/ebe1cnyd2gm836a/populations.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com/cd/0/inline/B09LWOJ_i2cLs10euDadv2NNyOjuZnXHC177fIVBI9wy5agg47OGs6rnXpX8oLxYxG8rQ9-VLzl9GG_Doh5H9lMvqr-Hpb3dz2TZPUPjOpl79BH4XWcYLS5mjmlao4G9DEq9NT8sCtjFmmOJdYPsm8dblEfNK1iaWCjpOgLts9msrA/file# [following]
# --2023-01-20 21:07:06--  https://uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com/cd/0/inline/B09LWOJ_i2cLs10euDadv2NNyOjuZnXHC177fIVBI9wy5agg47OGs6rnXpX8oLxYxG8rQ9-VLzl9GG_Doh5H9lMvqr-Hpb3dz2TZPUPjOpl79BH4XWcYLS5mjmlao4G9DEq9NT8sCtjFmmOJdYPsm8dblEfNK1iaWCjpOgLts9msrA/file
# Resolving uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com (uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com)... 162.125.69.15
# Connecting to uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com (uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com)|162.125.69.15|:443... connected.
# WARNING: cannot verify uc2c6b44241597daa08c4f760e19.dl.dropboxusercontent.com's certificate, issued by 'CN=DigiCert TLS RSA SHA256 2020 CA1,O=DigiCert Inc,C=US':
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 525 [text/plain]
# Saving to: 'data/populations.txt.4'
#
#      0K                                                       100%  978K=0.001s
#
# 2023-01-20 21:07:06 (978 KB/s) - 'data/populations.txt.4' saved [525/525]

# %% [markdown]
# 4\. **FFT of an image**
#
# Write a filter that removes the periodic noise from the `moonlanding.png` image by using a 2-dimensional FFT.
#
# * Import the image as a 2D numpy array using `plt.imread("images/moonlanding.png")`. Examine the image with `plt.imshow()`, which is heavily contaminated with periodic noise.
# * Check the documentation of the `scipy.fftpack` package, and find the method that performs a 2D FFT. Plot the spectrum (Fourier transform of) the image. **Hint**: use `LogNorm` to plot the colors in log scale:
# ```Python
# from matplotlib.colors import LogNorm
# plt.imshow(image, norm=LogNorm(vmin=5))
# ```
# * Inspect the spectrum, and try to locate the regions of the power spectrum that contain the signal and those which contain the periodic noise. Use array slicing to set the noise regions to zero.
# * Apply the inverse Fourier transform to plot the resulting image.

# %%
#Import the image as 2D numpy array
image1 = plt.imread("images/moonlanding.png")
plt.imshow(image1)

# %%
image_fft = fftpack.fft2(image)
image_abs = np.abs(image_fft)
plt.imshow(image_abs, norm=LogNorm(vmin=5))
plt.colorbar()
plt.show()

# %%
#Inspecting the spectrum
value = 100.
filt = np.where(image_abs <= value)
image_fft[filt] = 0
im_abs = np.abs(image_fft)
plt.imshow(im_abs, norm=LogNorm(vmin=5))

# %%
#Apply the inverse Fourier transform to plot the resulting image.
filtered_im = fftpack.ifft2(image_fft)
plt.imshow(np.real(filtered_im))
plt.show()
